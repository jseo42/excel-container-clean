# %%
import pandas as pd
from modules.customer import clean_customer_column
from modules.cntr import clean_cntr_column
from modules.size import clean_size_column
from modules.dates import clean_date_column
from modules.ssl import clean_ssl_column
from modules.time import clean_time_column_with_misc
from modules.pu import clean_pu_column_with_misc
from modules.inv import clean_inv_status_column
from modules.rail import clean_rail_column


# Load the Excel file
file_path = 'Data/ABL CNTR - Copy.xlsx'  # Replace with actual path
excel_data = pd.ExcelFile(file_path)

# Selected sheets to process
selected_sheets = ['JUL 2024', 'AUG 2024', 'SEP 2024', 'OCT 2024', 'NOV 2024']

# List of date columns to process
date_columns = ['ETA PORT', 'ETA', 'APPT', 'LFD', 'OG', 'IG']

# Dictionary to store cleaned data for saving
cleaned_sheets = {}

# Process each selected sheet
for sheet_name in selected_sheets:
    if sheet_name in excel_data.sheet_names:
        print(f"\nProcessing sheet: {sheet_name}")
        sheet_data = excel_data.parse(sheet_name)
        
        # Clean the CUSTOMER column
        if 'CUSTOMER' in sheet_data.columns:
            sheet_data['CUSTOMER'] = clean_customer_column(sheet_data['CUSTOMER'])
        
        # Clean the CNTR# column
        if 'CNTR#' in sheet_data.columns:
            sheet_data['CNTR#'] = clean_cntr_column(sheet_data['CNTR#'])
        
        # Clean the SIZE column
        if 'SIZE' in sheet_data.columns:
            sheet_data['SIZE'] = clean_size_column(sheet_data['SIZE'])
        
        # Clean all date columns
        for date_col in date_columns:
            if date_col in sheet_data.columns:
                print(f"\nCleaning date column: {date_col}")
                sheet_data[date_col] = clean_date_column(sheet_data[date_col], date_col)
        
        # Clean the SSL column
        if 'SSL' in sheet_data.columns:
            print(f"\nCleaning SSL column in sheet: {sheet_name}")
            sheet_data['SSL'] = clean_ssl_column(sheet_data['SSL'])

        # Clean the TIME column
        if 'TIME' in sheet_data.columns:
            print(f"\nCleaning TIME column in sheet: {sheet_name}")
            sheet_data = clean_time_column_with_misc(sheet_data, "TIME")
        
        # Clean PU# Column and create PU# MISC
        if 'PU#' in sheet_data.columns:
            print(f"\nCleaning PU# column in sheet: {sheet_name}")
            sheet_data = clean_pu_column_with_misc(sheet_data, "PU#")

        # Clean Inv Status column and create Inv # column
        if 'Inv status' in sheet_data.columns:
            print(f"\nCleaning 'Inv status' column in sheet: {sheet_name}")
            sheet_data = clean_inv_status_column(sheet_data, "Inv status")

        # Clean Rail Column    
        if 'Rail' in sheet_data.columns:
            print(f"\nCleaning Rail column in sheet: {sheet_name}")
            sheet_data = clean_rail_column(sheet_data, "Rail")
        
        # Store the cleaned sheet for saving
        cleaned_sheets[sheet_name] = sheet_data

# Save the cleaned data back to a new Excel file
output_file_path = 'cleaned_data_with_fixed_Rail.xlsx'
with pd.ExcelWriter(output_file_path, engine='openpyxl') as writer:
    for sheet_name, sheet_data in cleaned_sheets.items():
        sheet_data.to_excel(writer, sheet_name=sheet_name, index=False)

print(f"\nCleaned data has been saved to {output_file_path}")
# Out:
# Processing sheet: JUL 2024
#
# Original CUSTOMER column:
# ['ANO' 'APEX' 'ASPEED' 'Blue Star' 'BLUESTAR' 'China interocean' 'CIF'
#  'CTS' 'HUIHEJIU' 'KAIYA' 'KDW' 'KRAKEN' 'KYLIN' 'LINK TRANS' 'LITELOGO'
#  'META' 'NBJD' 'nbjd' 'NINGBO NAUHUA' 'NINGBO\xa0NAUHUA' 'NIUKU'
#  'PENAVICO' 'PG-NETWORK' 'PICO' 'ROHANA' 'SA UNION' 'SUPERFLYG '
#  'TEMU DE WELL' 'Titan' 'Uline' 'VAST LOG' 'WAYOTA' 'WEITU' 'Wing Ocean'
#  'YIWU HANGJI' 'YIXIN 桐乡意信']
#
# Cleaned CUSTOMER column after mapping:
# ['ANO' 'APEX' 'ASPEED' 'BLUE STAR' 'CHINA INTEROCEAN' 'CIF' 'CTS'
#  'HUIHEJIU' 'KAIYA' 'KDW' 'KRAKEN' 'KYLIN' 'LINK TRANS' 'LITELOGO' 'META'
#  'NBJD' 'NINGBO NAUHUA' 'NINGBO\xa0NAUHUA' 'NIUKU' 'PENAVICO' 'PG-NETWORK'
#  'PICO' 'ROHANA' 'SA UNION' 'SUPERFLYG' 'TEMU DE WELL' 'TITAN' 'ULINE'
#  'VAST LOG' 'WAYOTA' 'WEITU' 'WING OCEAN' 'YIWU HANGJI' 'YIXIN 桐乡意信']
#
# Original CNTR# column:
# 0    TRHU4903652
# 1    CAIU4354339
# 2    GAOU6228832
# 3    HMMU6157738
# 4    HMMU6535247
# Name: CNTR#, dtype: object
#
# Cleaned CNTR# column:
# 0      TRHU4903652
# 1      CAIU4354339
# 2      GAOU6228832
# 3      HMMU6157738
# 4      HMMU6535247
#           ...
# 176    GCXU6060817
# 177    BEAU5154860
# 178    TRHU5013801
# 179    OOCU7510584
# 180    TRHU8842679
# Name: CNTR#, Length: 181, dtype: object
#
# Original SIZE column:
# ['40HQ' '40 HQ' '20GP' '40GP' '20 GP' 'ftl']
#
# Cleaned SIZE column:
# ['40HQ' '20GP' '40GP' 'FTL']
#
# Cleaning date column: ETA PORT
#
# Processing column: ETA PORT
# Original values:
# 0   2024-06-27
# 1   2024-06-28
# 2   2024-07-09
# 3   2024-06-17
# 4   2024-07-09
# Name: ETA PORT, dtype: datetime64[ns]
# Cleaned values:
# 0   2024-06-27
# 1   2024-06-28
# 2   2024-07-09
# 3   2024-06-17
# 4   2024-07-09
# Name: ETA PORT, dtype: datetime64[ns]
#
# Cleaning date column: ETA
#
# Processing column: ETA
# Original values:
# 0   2024-07-05
# 1   2024-07-23
# 2   2024-07-19
# 3   2024-07-19
# 4   2024-07-23
# Name: ETA, dtype: datetime64[ns]
# Cleaned values:
# 0   2024-07-05
# 1   2024-07-23
# 2   2024-07-19
# 3   2024-07-19
# 4   2024-07-23
# Name: ETA, dtype: datetime64[ns]
#
# Cleaning date column: APPT
#
# Processing column: APPT
# Original values:
# 0    2024-07-10 00:00:00
# 1    2024-07-29 00:00:00
# 2    2024-07-23 00:00:00
# 3    2024-07-19 00:00:00
# 4                    NaN
# Name: APPT, dtype: object
# Cleaned values:
# 0   2024-07-10
# 1   2024-07-29
# 2   2024-07-23
# 3   2024-07-19
# 4          NaT
# Name: APPT, dtype: datetime64[ns]
#
# Cleaning date column: LFD
#
# Processing column: LFD
# Original values:
# 0    2024-07-07 00:00:00
# 1    2024-07-26 00:00:00
# 2    2024-07-23 00:00:00
# 3    2024-07-20 00:00:00
# 4    2024-07-26 00:00:00
# Name: LFD, dtype: object
# Cleaned values:
# 0   2024-07-07
# 1   2024-07-26
# 2   2024-07-23
# 3   2024-07-20
# 4   2024-07-26
# Name: LFD, dtype: datetime64[ns]
#
# Cleaning date column: OG
#
# Processing column: OG
# Original values:
# 0    2024-07-07 00:00:00
# 1    2024-07-26 00:00:00
# 2    2024-07-23 00:00:00
# 3    2024-07-19 00:00:00
# 4    2024-07-25 00:00:00
# Name: OG, dtype: object
# Cleaned values:
# 0   2024-07-07
# 1   2024-07-26
# 2   2024-07-23
# 3   2024-07-19
# 4   2024-07-25
# Name: OG, dtype: datetime64[ns]
#
# Cleaning date column: IG
#
# Processing column: IG
# Original values:
# 0   2024-07-12
# 1   2024-07-29
# 2   2024-07-23
# 3   2024-07-22
# 4   2024-07-26
# Name: IG, dtype: datetime64[ns]
# Cleaned values:
# 0   2024-07-12
# 1   2024-07-29
# 2   2024-07-23
# 3   2024-07-22
# 4   2024-07-26
# Name: IG, dtype: datetime64[ns]
#
# Cleaning SSL column in sheet: JUL 2024
#
# Original SSL column unique values:
# ['COSCO' 'HMM' 'YML' 'CMA' 'ZIM' 'OOCL' 'ONE' 'EVERGREEN' 'na' 'CMA CGM'
#  'SML' 'oocl' 'HAPAG' 'EMC' 'MAERSK' 'MATSON' 'MSC' 'WANHAI']
#
# Cleaned SSL column unique values:
# ['COSCO' 'HMM' 'YML' 'CMA' 'ZIM' 'OOCL' 'ONE' 'EVERGREEN' 'NA' 'CMA CGM'
#  'SML' 'HAPAG' 'EMC' 'MAERSK' 'MATSON' 'MSC' 'WANHAI']
#
# Cleaning TIME column in sheet: JUL 2024
#
# Processing column: TIME
#
# Valid TIME entries in TIME:
# ['' datetime.time(11, 0) datetime.time(9, 0) datetime.time(10, 0)
#  datetime.time(16, 20) datetime.time(0, 0)]
#
# Invalid TIME entries moved to TIME MISC:
# ['DROP' '10AM' nan '' '7:30AM' '6am' '7am' '9am' '12PM' '10am-11am' '8am'
#  '11am' '要打印一份PL交收货人when delivery' 'Dropped' '9:00:00 AM / unloaded'
#  '8:30am-5pm' 'DROP  8am-3pm.' '1 pm / drop' 'DFW delivery' '10am'
#  'NO APPT is required' '\xa0' 'DROP 09:00-15:00 ' 'morning' '2pm'
#  'ISA# 104388034980']
#
# Cleaning PU# column in sheet: JUL 2024
#
# Processing column: PU#
#
# Valid PU# entries in PU#:
# ['1D8053' '' 'C0E1DB' '112B7D' 'D58548' '7D6568' '6AD94B' '3FDE8E'
#  '9156A7' 'C33CF6' 'D55297' '2F671D' '00C1D4' '6F7EE1' 'B1D2B1' 'CC108F'
#  '1C33E1' 'B2F42A' '529A91' 'C6AE42' '340DF5' 'C7032F' 'B8E0D6' '30B6A0'
#  '0A02E6' 'EFFE75' '1D9FFC' 'A496FF' 'B23944' 'C9C46A' 'EF1BCD' 'A09CB6'
#  'EEEDDB' 'A2CF80' 'B461B3' 'EF176E' '492B81' 'B562E3' '982693' '19E2F2'
#  'B85866' '3BA1C7' 'E24AD3' 'FC29A7' '4BC905' '9486F8' 'F4690A' '90795A'
#  '28485F' '4BC876' '290D13' 'F8C1B4' '643AC9' '2F3918' 'D62B6C' 'EC5C59'
#  'D9A624' '087E50' 'C08F83' '3D05B1' 'E629BF' '0BEB5D' '27C527' '888F5E'
#  '934B7D' '53ACF8' '1A21B5' 'D1E621' '1D4060' 'E1080B' '963130' '42E65B'
#  'F34D69' '91CAC6' '59854E' '16C608' '86C235' 'DAF83C' 'BB1EC2' '899DE2'
#  '8BC4DC' 'A373AC' 'DB6EDA' '6D846F' '0470BE']
#
# Invalid PU# entries moved to PU# MISC:
# [nan 2697828 3321577 1832219 2697780 3321573 3930112 '3242881' '3243076'
#  1981337 '' 2692415 'Customs released' 2551087 '2550923' 3701385 2550837
#  3701689 3337812 3698959 '收到客户HC付款' 2830 5711 'Scheduled for pick up 8/13'
#  2820 3406 'AN sent' '650E96\xa0\xa0\xa0' '1CD11F\xa0\xa0' 1351 2807527
#  3080123 'Customs Rls' 'CUSTOMS RLEASED' 1720791 1720788 2817955 1659272
#  2818039 1659265 1659261 4207979 3261853 3260522 3793758 2818056
#  'ED0F2F\xa0\xa0' 1803 '959C0B \xa0' 'A80D9F \xa0' '3745' '4AE009 \xa0'
#  '8EC6BB ' 6090 'R00120777906']
#
# Cleaning 'Inv status' column in sheet: JUL 2024
#
# Processing column: Inv status
# Available columns: ['CUSTOMER', 'CNTR#', 'SIZE', 'ETA PORT', 'ETA', 'SSL', 'Rail', 'APPT', 'TIME', 'TIME MISC', 'TRUCKER', 'TO', 'PU#', 'PU# MISC', 'LFD', 'OG', 'IG', 'NOTE', 'OP', 'Inv status', 'Dispatch', 'Sales Amount', 'Cost', 'CNTR AMOUNT', 'Profit', 'Profit Ratio', 'EIR', 'Co-loader']
#
# Extracted Inv Number:
# 0       NaN
# 1    151838
# 2    151489
# 3    151488
# 4    152044
# Name: Inv status, dtype: object
#
# Updated Inv status column:
# ['' 'DONE']
#
# Generated Inv Number column:
# ['' '151838' '151489' '151488' '152044' '151491' '151903' '151686'
#  '151994' '151667' '150816' '152191' '152167' '152046' '152083' '152534'
#  '151141' '151127' '151166' '152607' '152600' '153205' '153206' '152626'
#  '152610' '153187' '153192' '151662' '151131' '151129' '150700' '150015'
#  '150035' '150696' '150031' '150534 to customer/ 150627 to Wuhan' '150562'
#  '151136' '151977' '152204' '152051' '150697' '150028' '150011' '150255'
#  '150010' '150256' '150012' '150253' '151965' '150257' '152048' '150259'
#  '150810' '151025' '150807' '150808' '150806' '152632']
#
# Cleaning Rail column in sheet: JUL 2024
#
# Processing column: Rail
#
# Updated Rail column:
# ['BNSF' 'UP' 'UP GLOBAL 4' 'UNION PACIFIC - GLOBAL4' 'BNSF DENVER'
#  'NORFORK PORT' 'BNSF LPC' 'CN RAIL' 'CP RAIL - CHICAGO, BENSENVILLE'
#  'CHARLESTON, SC -WWT (WANDO WELCH TERMINAL)'
#  'CONTAINER PORT BERTHS 1-5 GARDEN CITY TERMINALS\nSAVANNAH'
#  'CONTAINER PORT BERTHS 1-5 - L738' 'NYCT'
#  'MAHER TERM BLDG 2180 CDS - E416' 'CONTAINER PORT BERTHS 1-5 -L738'
#  'GARDEN CITY TERMINAL' 'CP' 'CN' 'UNKNOWN'
#  'LAX- EVERGREEN CONTAINER TML Y124' 'NS LOUISVILLE' 'MIAMI POMTOC'
#  'BAY PORT CONTAINER TERMINAL' 'JACKSONVILLE SEROJA LIMA'
#  'SAVANNAH GARDEN CITY TERMINAL' 'PORT OF TAMPA' 'BNSF-FORT WORTH,TX'
#  'NS COLUMBUS' 'TACOMA' 'LAX-APM TML' 'LGB-TTI TERMINAL' 'LAX- APM TML'
#  'BNSF - ALLIANCE' 'BNSF DALLAS' 'UP RAIL - DALLAS (DIT)'
#  'TRAPAC LOS ANGELES' 'LONG BEACH, CA' 'PHILADELPHIA, PA'
#  'NS CINCINNATI,OH' 'NS ATL' 'NS-APPLIANCE PARK' 'CSX CINCINNATI'
#  'LBCT TERMINAL' 'LBCT']
#
# Processing sheet: AUG 2024
#
# Original CUSTOMER column:
# ['KRAKEN' 'LINK TRANS' 'NIUKU' 'PG-NETWORK' 'SA UNION' 'SUNNY WING'
#  'YIWU HANGJI' 'NINGBO NANHUA' 'FOREST-SHENZHEN' 'FOREST-NINGBO' 'UQI'
#  'Blue Star' 'KAIYA' 'fin whale' 'ROHANA' 'ASPEED' 'SUPERFLYG ' 'Titan'
#  'Apex' 'HUIHEJIU' 'kai qi' 'WAYOTA' 'APEX' 'META' 'PENAVICO-SPEY' 'ANO'
#  'Wing Ocean' 'Meta' 'PICO' 'Niwo' 'China interocean' 'Uline'
#  'FOREST- NINGBO' 'VAST LOG' 'FOREST- SHENZHEN']
#
# Cleaned CUSTOMER column after mapping:
# ['KRAKEN' 'LINK TRANS' 'NIUKU' 'PG-NETWORK' 'SA UNION' 'SUNNY WING'
#  'YIWU HANGJI' 'NINGBO NANHUA' 'FOREST-SHENZHEN' 'FOREST-NINGBO' 'UQI'
#  'BLUE STAR' 'KAIYA' 'FIN WHALE' 'ROHANA' 'ASPEED' 'SUPERFLYG' 'TITAN'
#  'APEX' 'HUIHEJIU' 'KAI QI' 'WAYOTA' 'META' 'PENAVICO-SPEY' 'ANO'
#  'WING OCEAN' 'PICO' 'NIWO' 'CHINA INTEROCEAN' 'ULINE' 'VAST LOG']
#
# Original CNTR# column:
# 0       ONEU9208054
# 1       SEGU4210025
# 2       TIIU4644074
# 3       ONEU1175102
# 4    TCLU9545925
# Name: CNTR#, dtype: object
#
# Cleaned CNTR# column:
# 0      ONEU9208054
# 1      SEGU4210025
# 2      TIIU4644074
# 3      ONEU1175102
# 4      TCLU9545925
#           ...
# 169    OOLU8977991
# 170    MAGU5181396
# 171    ZCSU6790474
# 172    GAOU7152198
# 173    EGHU8223786
# Name: CNTR#, Length: 174, dtype: object
#
# Original SIZE column:
# ['40 HQ' '40HQ' nan '20GP' '40GP' 'ftl' '20DV' '45 HC']
#
# Cleaned SIZE column:
# ['40HQ' 'UNKNOWN' '20GP' '40GP' 'FTL' '20DV' '45 HC']
#
# Cleaning date column: ETA PORT
#
# Processing column: ETA PORT
# Original values:
# 0    2024-06-30 00:00:00
# 1    2024-07-18 00:00:00
# 2    2024-07-19 00:00:00
# 3    2024-07-19 00:00:00
# 4    2024-07-19 00:00:00
# Name: ETA PORT, dtype: object
# Cleaned values:
# 0   2024-06-30
# 1   2024-07-18
# 2   2024-07-19
# 3   2024-07-19
# 4   2024-07-19
# Name: ETA PORT, dtype: datetime64[ns]
#
# Cleaning date column: ETA
#
# Processing column: ETA
# Original values:
# 0   2024-08-01
# 1   2024-08-01
# 2   2024-08-01
# 3   2024-08-01
# 4   2024-08-02
# Name: ETA, dtype: datetime64[ns]
# Cleaned values:
# 0   2024-08-01
# 1   2024-08-01
# 2   2024-08-01
# 3   2024-08-01
# 4   2024-08-02
# Name: ETA, dtype: datetime64[ns]
#
# Cleaning date column: APPT
#
# Processing column: APPT
# Original values:
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3    2024-08-03 00:00:00
# 4    2024-08-05 00:00:00
# Name: APPT, dtype: object
# Cleaned values:
# 0          NaT
# 1          NaT
# 2          NaT
# 3   2024-08-03
# 4   2024-08-05
# Name: APPT, dtype: datetime64[ns]
#
# Cleaning date column: LFD
#
# Processing column: LFD
# Original values:
# 0    2024-08-03 00:00:00
# 1    2024-08-03 00:00:00
# 2    2024-08-03 00:00:00
# 3    2024-08-03 00:00:00
# 4    2024-08-05 00:00:00
# Name: LFD, dtype: object
# Cleaned values:
# 0   2024-08-03
# 1   2024-08-03
# 2   2024-08-03
# 3   2024-08-03
# 4   2024-08-05
# Name: LFD, dtype: datetime64[ns]
#
# Cleaning date column: OG
#
# Processing column: OG
# Original values:
# 0    2024-08-02 00:00:00
# 1    2024-08-03 00:00:00
# 2    2024-08-03 00:00:00
# 3    2024-08-03 00:00:00
# 4    2024-08-05 00:00:00
# Name: OG, dtype: object
# Cleaned values:
# 0   2024-08-02
# 1   2024-08-03
# 2   2024-08-03
# 3   2024-08-03
# 4   2024-08-05
# Name: OG, dtype: datetime64[ns]
#
# Cleaning date column: IG
#
# Processing column: IG
# Original values:
# 0   2024-08-05
# 1   2024-08-05
# 2   2024-08-04
# 3   2024-08-05
# 4   2024-08-05
# Name: IG, dtype: datetime64[ns]
# Cleaned values:
# 0   2024-08-05
# 1   2024-08-05
# 2   2024-08-04
# 3   2024-08-05
# 4   2024-08-05
# Name: IG, dtype: datetime64[ns]
#
# Cleaning SSL column in sheet: AUG 2024
#
# Original SSL column unique values:
# ['ONE' 'OOCL' 'COSCO' 'ONE ' 'HAPAG' 'MSC' 'SML' 'Maersk' 'ZIM' 'HMM'
#  'YML' 'EVERGREEN' 'CMA' 'WANHAI' 'na' 'Evergreen' 'COSCO ' 'MAERSK' 'MSK'
#  'MATSON' 'YMM']
#
# Cleaned SSL column unique values:
# ['ONE' 'OOCL' 'COSCO' 'HAPAG' 'MSC' 'SML' 'MAERSK' 'ZIM' 'HMM' 'YML'
#  'EVERGREEN' '' 'CMA' 'WANHAI' 'NA' 'MSK' 'MATSON' 'YMM']
#
# Cleaning TIME column in sheet: AUG 2024
#
# Processing column: TIME
#
# Valid TIME entries in TIME:
# ['' datetime.time(8, 0) datetime.time(12, 0) datetime.time(9, 0)
#  datetime.time(10, 30) datetime.time(11, 0) datetime.time(10, 0)
#  datetime.time(9, 30)]
#
# Invalid TIME entries moved to TIME MISC:
# ['' '7am' '9am' '10am' '8am' '11am' nan 'Sojin Handles' '7:00-8:00 am'
#  '8:30AM DROP ' '1PM' 'EXAM HOLD \nDetorit ' '\xa09am' '2pm - 4:30 pm '
#  '12:30pm' 'morning' '9:30am' '11AM']
#
# Cleaning PU# column in sheet: AUG 2024
#
# Processing column: PU#
#
# Valid PU# entries in PU#:
# ['' '6A6E3F' '0569F7' 'A71EFD' '8B563D' '2BF363' '02F4D2' 'B0365C'
#  '3D7B91' 'C269A9' '5BE152' 'F3D20F' 'B636B8' '21968A' '204D4C' '0AF21A'
#  '676A42' '009225' 'BCFFE3' 'E11110' '919F41' 'A3498B' '83CEF3' 'B0E1B3'
#  '07294F' 'C6461D' 'E0F1C2' '91BEF1' '7EC030' 'C76048' 'ABE7A0' '66A926'
#  'C79C09' '8C4B33' '4B86FD' '8AF8D3' '0DB57B' '3B7F67' '6F2179' 'C6DA36'
#  '1482F7' '3D4CC9' '4FCB26' '38FA9A' 'AD8103' '791EFF' '541A84' 'D9857A'
#  '59196F' 'F078F0' 'BB81F5' 'AE6177' '5B2BBB' '05D45A' '45A924' 'D2EB47'
#  '686BFA' '238F16' 'D72404' 'CF11FB' '5533C7' '507C46' '28832A' '9BD1A1'
#  'A3B221' '69B359' '3BFB61' '3B62E7' '1C1035']
#
# Invalid PU# entries moved to PU# MISC:
# [2856637 nan 4004766 4004771 '' '’535284 ' 'R00121826262' 3701321 3701582
#  'AN sent' 33215 33216 '‘921500' 4373546 '0BC1ED ' '3996212'
#  '61678/127703' 4707569 'Customs RLS / LINE HOLD removed' '#052636' 1867
#  'D0744F  ' 'PO# 33217' 69422908 '#060319' 5269988 4707467 4707343 4707478
#  5365774 '4707258' 4790737 '3122 from NS' 5848846 5848856 4790711 4790765
#  '6C4E8E ' '‘2273' 4538 'PO# 61679' 'PO# 61720' 4332227 2616 '05A634 '
#  5159406 'Customs RLS /  TLX HBL' 61677 5272991 5179559 5179440 5695835
#  5695779 4929303 2022 '7028B9 ' '6869BC\xa0' 7068611]
#
# Cleaning 'Inv status' column in sheet: AUG 2024
#
# Processing column: Inv status
# Available columns: ['CUSTOMER', 'CNTR#', 'SIZE', 'ETA PORT', 'ETA', 'SSL', 'Rail', 'APPT', 'TIME', 'TIME MISC', 'TRUCKER', 'TO', 'PU#', 'PU# MISC', 'LFD', 'OG', 'IG', 'NOTE', 'OP', 'Inv status', 'Dispatch', 'Sales Amount', 'Cost', 'CNTR AMOUNT', 'Profit', 'Profit Ratio', 'EIR', 'Co-loader']
#
# Extracted Inv Number:
# 0    NaN
# 1    NaN
# 2
# 3    NaN
# 4    NaN
# Name: Inv status, dtype: object
#
# Updated Inv status column:
# ['' 'DONE']
#
# Generated Inv Number column:
# ['' '151677' '153989' '152685' '153108' '152406' '153344' '152910'
#  '152696' '152918' '152695' '152922' '152925' '154313' '152698' '151240'
#  '153105' '153106' '154637' '153109' '153535' '152283' '155198' '153172'
#  '153180' '152501' '152494' '152004' '153173' '154639' '153179' '153266'
#  '152627' '152160' '152162' '153210' '153439' '154664']
#
# Cleaning Rail column in sheet: AUG 2024
#
# Processing column: Rail
#
# Updated Rail column:
# ['UP' 'BNSF' 'LAX' 'CP' 'CSX CINCINNATI J614'
#  'TOTAL TERMINALS INTERNATIONAL' 'MOBILE, AL' 'BNSF LPC' 'UNKNOWN'
#  'TACOMA, WA' 'JACKSONVILLE-BLOUNT ISLAND MARINE TML'
#  'LGB PORT-PCT TERMINAL' 'CN RAIL - CHICAGO (HARVEY)' 'NS CLEVELAND, OH'
#  'GCT BAYONE' 'ATLANTA,GA,FULTON,UNITED STATES-CSX' 'CN HARVEY'
#  'CN RAIL - HARVEY' 'NS DETROIT LIVERNOIS' 'BNSF-KANSAS CITY'
#  'UP-SALT LAKE CITY' 'SAVANNAH PORT AUTHORITY (L738)' 'NS-AUSTELL'
#  'MOBILE CONTAINER TERMINAL ( R103 )' 'NS LOUISVILLE,KY' 'PORT OF TAMPA'
#  'OAKLAND, CA' 'SOUTH FLORIDA CONTAINER TER' 'NS CINCINNATI,OH'
#  'BOSTON PORT-PAUL W. CONLEY MARINE TMNL' 'UP-GLOBAL 4'
#  'LONG BEACH CONTAINER TERMINAL (PIER E)']
#
# Processing sheet: SEP 2024
#
# Original CUSTOMER column:
# ['Forest - Hunan' 'China interocean' 'SUNNY WING' 'YIWU HANGJI'
#  'PG-NETWORK' 'Rabbit Speed  兔兔及时达' 'WAYOTA' 'LINK TRANS' 'SA UNION'
#  'Meta' 'PENAVICO-SPEY' 'NINGBO NANHUA' 'PICO' 'APEX' 'Wing Ocean'
#  'HUIHEJIU' 'Apex' 'FOREST- NINGBO' 'META' 'SF' 'FOREST- SHENZHEN'
#  'WING SHIP 厦门翼舟' 'Xin Bang' 'XTD' 'weitu' 'FOREST- CHANGSHA' 'ROHANA'
#  'MILE' nan]
#
# Cleaned CUSTOMER column after mapping:
# ['FOREST-HUNAN' 'CHINA INTEROCEAN' 'SUNNY WING' 'YIWU HANGJI' 'PG-NETWORK'
#  'RABBIT SPEED' 'WAYOTA' 'LINK TRANS' 'SA UNION' 'META' 'PENAVICO-SPEY'
#  'NINGBO NANHUA' 'PICO' 'APEX' 'WING OCEAN' 'HUIHEJIU' 'FOREST-NINGBO'
#  'SF' 'FOREST-SHENZHEN' 'WING SHIP' 'XIN BANG' 'XTD' 'WEITU'
#  'FOREST-CHANGSHA' 'ROHANA' 'MILE' 'NAN']
#
# Original CNTR# column:
# 0    ZCSU8859230
# 1    TRDU6816790
# 2    TRDU6816681
# 3    WHSU6348751
# 4    WHSU5685465
# Name: CNTR#, dtype: object
#
# Cleaned CNTR# column:
# 0      ZCSU8859230
# 1      TRDU6816790
# 2      TRDU6816681
# 3      WHSU6348751
# 4      WHSU5685465
#           ...
# 130            NAN
# 131            NAN
# 132            NAN
# 133            NAN
# 134            NAN
# Name: CNTR#, Length: 135, dtype: object
#
# Original SIZE column:
# ['40HQ' '20GP' '40GP' '40HC' 'FTL' nan]
#
# Cleaned SIZE column:
# ['40HQ' '20GP' '40GP' '40HC' 'FTL' 'UNKNOWN']
#
# Cleaning date column: ETA PORT
#
# Processing column: ETA PORT
# Original values:
# 0   2024-08-15
# 1   2024-08-11
# 2   2024-08-11
# 3   2024-09-01
# 4   2024-09-01
# Name: ETA PORT, dtype: datetime64[ns]
# Cleaned values:
# 0   2024-08-15
# 1   2024-08-11
# 2   2024-08-11
# 3   2024-09-01
# 4   2024-09-01
# Name: ETA PORT, dtype: datetime64[ns]
#
# Cleaning date column: ETA
#
# Processing column: ETA
# Original values:
# 0   2024-08-30
# 1   2024-09-01
# 2   2024-09-01
# 3   2024-09-01
# 4   2024-09-01
# Name: ETA, dtype: datetime64[ns]
# Cleaned values:
# 0   2024-08-30
# 1   2024-09-01
# 2   2024-09-01
# 3   2024-09-01
# 4   2024-09-01
# Name: ETA, dtype: datetime64[ns]
#
# Cleaning date column: APPT
#
# Processing column: APPT
# Original values:
# 0                    NaN
# 1    2024-09-04 00:00:00
# 2    2024-09-04 00:00:00
# 3    2024-09-05 00:00:00
# 4    2024-09-06 00:00:00
# Name: APPT, dtype: object
# Cleaned values:
# 0          NaT
# 1   2024-09-04
# 2   2024-09-04
# 3   2024-09-05
# 4   2024-09-06
# Name: APPT, dtype: datetime64[ns]
#
# Cleaning date column: LFD
#
# Processing column: LFD
# Original values:
# 0   2024-09-01
# 1   2024-09-04
# 2   2024-09-04
# 3   2024-09-06
# 4   2024-09-06
# Name: LFD, dtype: datetime64[ns]
# Cleaned values:
# 0   2024-09-01
# 1   2024-09-04
# 2   2024-09-04
# 3   2024-09-06
# 4   2024-09-06
# Name: LFD, dtype: datetime64[ns]
#
# Cleaning date column: OG
#
# Processing column: OG
# Original values:
# 0   2024-09-04
# 1   2024-09-04
# 2   2024-09-04
# 3   2024-09-04
# 4   2024-09-05
# Name: OG, dtype: datetime64[ns]
# Cleaned values:
# 0   2024-09-04
# 1   2024-09-04
# 2   2024-09-04
# 3   2024-09-04
# 4   2024-09-05
# Name: OG, dtype: datetime64[ns]
#
# Cleaning date column: IG
#
# Processing column: IG
# Original values:
# 0   2024-09-09
# 1   2024-09-04
# 2   2024-09-04
# 3   2024-09-05
# 4   2024-09-06
# Name: IG, dtype: datetime64[ns]
# Cleaned values:
# 0   2024-09-09
# 1   2024-09-04
# 2   2024-09-04
# 3   2024-09-05
# 4   2024-09-06
# Name: IG, dtype: datetime64[ns]
#
# Cleaning SSL column in sheet: SEP 2024
#
# Original SSL column unique values:
# ['ZIM' 'HMM' 'WANHAI' 'CMA' 'MSC' 'ONE' 'ONE ' 'EVERGREEN' 'OOCL' 'COSCO'
#  'MAERSK' 'HAPAG' 'YML' 'Matson' 'MATSON' 'MSK' 'Maersk']
#
# Cleaned SSL column unique values:
# ['ZIM' 'HMM' 'WANHAI' 'CMA' 'MSC' 'ONE' 'EVERGREEN' 'OOCL' 'COSCO'
#  'MAERSK' 'HAPAG' 'YML' 'MATSON' 'MSK' '']
#
# Cleaning TIME column in sheet: SEP 2024
#
# Processing column: TIME
#
# Valid TIME entries in TIME:
# ['' datetime.time(10, 0) datetime.time(15, 30) datetime.time(7, 0)
#  datetime.time(14, 0) datetime.time(13, 0) datetime.time(12, 0)
#  datetime.time(11, 0) datetime.time(9, 0) datetime.time(8, 0)]
#
# Invalid TIME entries moved to TIME MISC:
# ['' '8am, live ' '10am, live' '9am' '7am' '8am' nan '10am' 'DROP' '12pm'
#  '8:00am' 'APPPT1:15pm, \nDROP @ 2:02pm' '11am' '10am-12pm' 'DFW HANDLES']
#
# Cleaning PU# column in sheet: SEP 2024
#
# Processing column: PU#
#
# Valid PU# entries in PU#:
# ['' '6492DF' '0DC151' 'ACBB66' '02F6FA' '00B4F0' 'AB1D10' '05780F'
#  'CB81AD' '89CC76' '2FF910' 'E9550E' '8CAF59' 'F1A7D1' 'A16B2C' 'CFED6F'
#  '326F39' '782F2D' '832E54' '9155A1' 'DB4344' '09BCE3' '5A3CBF' 'A8A30E'
#  '950C7F' 'E9BD5D' '185C90' 'CA3544' '220BC4' '0F35F4' '757C2F' '9D6E1F'
#  '73ADF1' 'B14043' '6F7E4C' 'E6B01F' '18FD21' '85E82B' 'F904A2' 'F9F060'
#  '161C0A' '58D53B' 'B25662' 'FE5F9D' 'D52ED4' '73D1F0' 'D3E309' 'FE5741'
#  'FF024B' '1A0E23' '59EB45' '5585F5' 'A2722E' '1FA838' '94A5F4' '7AC37B'
#  '3F609F' '9C8F98' '841B95' '37B377']
#
# Invalid PU# entries moved to PU# MISC:
# [nan 6433217 6433215 '' 'Customs RLS' 'R00122482386' 6433202 '22AF49 '
#  5275229 '57F26A ' ' PO# 61813' 'PO# 61449' 5179558 'AN sent' 'PO# 61680'
#  1371 2929 6509 6439719 6453292 'FDD8CF\xa0 \xa0' 6453289 6453304 8057760
#  8071369 '6E1E82 ' 'AAAA40\xa0' 'CUSTOMS RLS /  TLX RLS' 'PO# 33218'
#  'PO# 61681' 7343625 'TLX HBL/ CUSTOMS RLS' 'R00123257266'
#  '5A9932\xa0 \xa0' 'PO# 33219' 'PO# 33220'
#  'ISF SENT/ PRE-ALERT SENT/ Customs RLS /  TLX HBL' 4559 '3F8B64 '
#  'F48549 ']
#
# Cleaning 'Inv status' column in sheet: SEP 2024
#
# Processing column: Inv status
# Available columns: ['CUSTOMER', 'CNTR#', 'SIZE', 'ETA PORT', 'ETA', 'SSL', 'Rail', 'APPT', 'TIME', 'TIME MISC', 'TRUCKER', 'TO', 'PU#', 'PU# MISC', 'LFD', 'OG', 'IG', 'NOTE', 'OP', 'Inv status', 'Dispatch', 'Sales Amount', 'Cost', 'CNTR AMOUNT', 'Profit', 'Profit Ratio', 'EIR', 'Co-loader']
#
# Extracted Inv Number:
# 0       NaN
# 1    153352
# 2    153548
# 3       NaN
# 4       NaN
# Name: Inv status, dtype: object
#
# Updated Inv status column:
# ['' 'DONE']
#
# Generated Inv Number column:
# ['' '153352' '153548' '153354' '153577' '153619' '153579' '135719'
#  '154095' '153615' '153101' '152834' '153170' '153578' '153576' '154218'
#  '153655' '153694' '153695' '153997' '154167' '153878' '153749' '153752'
#  '153753' '153103' '154197' '153612' '154094 / New  155556' '154322'
#  '154326' '153697' '154435' '154439' '154206' '154318' '154525' '153284'
#  '153874' '154766  Duty inv sent' '154726' '155329' '154192' '154196'
#  '154195' '153875']
#
# Cleaning Rail column in sheet: SEP 2024
#
# Processing column: Rail
#
# Updated Rail column:
# ['BNSF' 'UP-GLOBAL 4' "OAKLAND INT'L CTNR TML" 'BNSF LPC' 'CSX CINCINNATI'
#  'NORFOLK PORT-VIRGINIA INTERNATIONAL GATEWAY TML'
#  'SAVANNAH-GARDEN CITY TERMINAL' 'UP' 'TACOMA, WA' 'GARDEN CITY TERMINAL'
#  'BNSF-KANSAS CITY' 'MIAMI POMTOC' 'CN RAIL - CHICAGO (HARVEY)'
#  'NS-APPLIANCE PARK' 'NORFOLK SOUTERN - AUSTELL, GA' 'BNSF ATLANTA'
#  'MAHER TERMINAL' 'BNSF DENVER' 'LGB PORT-PCT TML' 'MOBILE, AL'
#  'BNSF KANSAS CITY' 'UP MEMPHIS' 'NYC-APM TERMINALS'
#  'UP-CSX - COLUMBUS-I699' 'BNSF DALLAS' 'LAX PORT-FENIX TML'
#  'NEW YORK-MAHER TERMINALS' 'NCSPA (WILMINGTON TERMINAL)' 'UNKNOWN']
#
# Processing sheet: OCT 2024
#
# Original CUSTOMER column:
# ['YIWU HANGJI' 'SA UNION' 'WAYOTA' 'Ningbo Nanhua' 'LINK TRANS' 'APEX'
#  'FOREST- SHENZHEN' 'ROHANA' 'ASPEED' 'EVANGEL' 'FOREST- NINGBO' 'Apex'
#  'META' 'Evangel' 'WING SHIP 厦门翼舟' '通途' 'VAST LOG' 'ABL WUHAN' 'Alexbest'
#  'PENAVICO-HAITIAN' 'Loadstar-ship ' '创辰' 'PICO' 'Loadstar-ship'
#  'PG-NETWORK' 'UQI' 'AGI' 'KUMI']
#
# Cleaned CUSTOMER column after mapping:
# ['YIWU HANGJI' 'SA UNION' 'WAYOTA' 'NINGBO NANHUA' 'LINK TRANS' 'APEX'
#  'FOREST-SHENZHEN' 'ROHANA' 'ASPEED' 'EVANGEL' 'FOREST-NINGBO' 'META'
#  'WING SHIP' '通途' 'VAST LOG' 'ABL WUHAN' 'ALEXBEST' 'PENAVICO-HAITIAN'
#  'LOADSTAR-SHIP' '创辰' 'PICO' 'PG-NETWORK' 'UQI' 'AGI' 'KUMI']
#
# Original CNTR# column:
# 0    FCIU7209306
# 1       EMCU1773255
# 2       EGSU9288656
# 3       DRYU9940312
# 4       TXGU6669964
# Name: CNTR#, dtype: object
#
# Cleaned CNTR# column:
# 0      FCIU7209306
# 1      EMCU1773255
# 2      EGSU9288656
# 3      DRYU9940312
# 4      TXGU6669964
#           ...
# 134    TRHU2555497
# 135    CSLU1366430
# 136    CSNU1184432
# 137    OOLU6815760
# 138    CSNU7529589
# Name: CNTR#, Length: 139, dtype: object
#
# Original SIZE column:
# ['40HQ' '40 HQ' '40’HQ' '20GP' '40HC' '40HQ\n\n' '40GP']
#
# Cleaned SIZE column:
# ['40HQ' '40’HQ' '20GP' '40HC' '40GP']
#
# Cleaning date column: ETA PORT
#
# Processing column: ETA PORT
# Original values:
# 0   2024-09-14
# 1   2024-10-01
# 2   2024-10-01
# 3   2024-08-03
# 4   2024-10-02
# Name: ETA PORT, dtype: datetime64[ns]
# Cleaned values:
# 0   2024-09-14
# 1   2024-10-01
# 2   2024-10-01
# 3   2024-08-03
# 4   2024-10-02
# Name: ETA PORT, dtype: datetime64[ns]
#
# Cleaning date column: ETA
#
# Processing column: ETA
# Original values:
# 0   2024-10-01
# 1   2024-10-01
# 2   2024-10-01
# 3   2024-10-02
# 4   2024-10-02
# Name: ETA, dtype: datetime64[ns]
# Cleaned values:
# 0   2024-10-01
# 1   2024-10-01
# 2   2024-10-01
# 3   2024-10-02
# 4   2024-10-02
# Name: ETA, dtype: datetime64[ns]
#
# Cleaning date column: APPT
#
# Processing column: APPT
# Original values:
# 0                                  2024-10-04 00:00:00
# 1                                  2024-10-08 00:00:00
# 2                                  2024-10-09 00:00:00
# 3    https://tas.wydgroup.com?booking_code=Z4DUK8 \...
# 4                                  2024-10-09 00:00:00
# Name: APPT, dtype: object
# Cleaned values:
# 0   2024-10-04
# 1   2024-10-08
# 2   2024-10-09
# 3          NaT
# 4   2024-10-09
# Name: APPT, dtype: datetime64[ns]
#
# Cleaning date column: LFD
#
# Processing column: LFD
# Original values:
# 0    2024-10-05 00:00:00
# 1    2024-10-08 00:00:00
# 2    2024-10-08 00:00:00
# 3    2024-10-03 00:00:00
# 4    2024-10-07 00:00:00
# Name: LFD, dtype: object
# Cleaned values:
# 0   2024-10-05
# 1   2024-10-08
# 2   2024-10-08
# 3   2024-10-03
# 4   2024-10-07
# Name: LFD, dtype: datetime64[ns]
#
# Cleaning date column: OG
#
# Processing column: OG
# Original values:
# 0   2024-10-04
# 1   2024-10-07
# 2   2024-10-08
# 3   2024-10-03
# 4   2024-10-07
# Name: OG, dtype: datetime64[ns]
# Cleaned values:
# 0   2024-10-04
# 1   2024-10-07
# 2   2024-10-08
# 3   2024-10-03
# 4   2024-10-07
# Name: OG, dtype: datetime64[ns]
#
# Cleaning date column: IG
#
# Processing column: IG
# Original values:
# 0    2024-10-04 00:00:00
# 1    2024-10-09 00:00:00
# 2    2024-10-14 00:00:00
# 3    2024-10-04 00:00:00
# 4    2024-10-10 00:00:00
# Name: IG, dtype: object
# Cleaned values:
# 0   2024-10-04
# 1   2024-10-09
# 2   2024-10-14
# 3   2024-10-04
# 4   2024-10-10
# Name: IG, dtype: datetime64[ns]
#
# Cleaning SSL column in sheet: OCT 2024
#
# Original SSL column unique values:
# ['OOCL' 'EVERGREEN' 'ONE' 'TS LINES' 'MAERSK' 'ZIM' 'HMM' 'MSC' 'SML'
#  'COSCO' 'CMA' 'YML' 'EMC' 'CMA CGM' 'COSU' 'Hapag' 'MSK' 'CMA-CGM'
#  'HAPAG']
#
# Cleaned SSL column unique values:
# ['OOCL' 'EVERGREEN' 'ONE' 'TS LINES' 'MAERSK' 'ZIM' 'HMM' 'MSC' 'SML'
#  'COSCO' 'CMA' 'YML' 'EMC' 'CMA CGM' 'COSU' 'HAPAG' 'MSK' 'CMA-CGM']
#
# Cleaning TIME column in sheet: OCT 2024
#
# Processing column: TIME
#
# Valid TIME entries in TIME:
# ['' datetime.time(8, 0) datetime.time(10, 0) datetime.time(9, 0)
#  datetime.time(11, 0) datetime.time(8, 30) datetime.time(7, 0)]
#
# Invalid TIME entries moved to TIME MISC:
# ['10am' '9am' nan 'DROP' '' '7AM-9AM' 'DFW Handles' '9AM' '11/2 @18:00'
#  datetime.datetime(2024, 10, 16, 0, 0) 'Customer Handles'
#  '8:30 - noon drop' '11AM' '10AM' datetime.datetime(2024, 10, 21, 0, 0)
#  datetime.datetime(2024, 10, 20, 0, 0) '6am'
#  datetime.datetime(2024, 10, 25, 0, 0)
#  datetime.datetime(2024, 10, 24, 0, 0) '1:00 - 2:30 Easter Time'
#  datetime.datetime(2024, 11, 4, 18, 0) '11/1/2024 10:00 CDT ' '3:30PM'
#  '8:30AM' '10:30AM' '2:30PM' '3:00PM']
#
# Cleaning PU# column in sheet: OCT 2024
#
# Processing column: PU#
#
# Valid PU# entries in PU#:
# ['595655' '' 'BCD4F5' 'A3117A' 'C5D390' '23C718' '22AE7D' '51D9A6'
#  '83C11C' '37B3F7' '4A4EDA' '9C6A40' '2231EE' '6D7A23' 'AAAA45' '53BB1E'
#  '82ECB4' 'D2A899' 'AD0D85' '64EE00' '8D82E8' '8C60E5' '04D8F1' 'D4FFEA'
#  'EEE678' 'F3933E' 'DF845E' '2FD1AC' '6EFDBF' '68761D' '84710C' '2FDDB4'
#  '218DDB' '84BA7F' '48A291' '08DF5F' '038545' '40180C' '5008AE' '6C506F'
#  '9B9888' '516D17' '96AE36' '6814A3' '4D78EB' '3D8A31' '8C9588' 'B31DC6'
#  'A47982' '58575D' '4ED491' 'D9DEE5' 'D1A381' '35F85B' 'C7C04B' '97D54E'
#  '943E32' '360D2D' '4E95FA' '362F18' '2AE252']
#
# Invalid PU# entries moved to PU# MISC:
# [nan 'PO# 62085' 'PO# 62086' 1535 61607 '39F25D ' 8845184 '091388 '
#  '‘8190252' 8790433 8790428 9103550 'AN sent' 9103675 9029843 9029700
#  '6E78C1 ' '2475E4 ' '0345021' '#088772' 'PO# 62088' 9024019 9103666
#  9103674 '7EF649    ' 'A0EAFD\xa0' 'Customs RLS' '' 2563 6028 5784 6247
#  9653236 9653344 'A9535D   ' 9029842 '0582C9\xa0 \xa0' 'PO# 62090' 9647398
#  6889 3209 '4685DB ' 'CAC0DF ' 'PO# 62089' 66354620
#  'Customs RLS /  TLX HBL\n6D7CE1' 1488507 '/00BFAC' 1488509 3246
#  '/0698905' 'Customs RLS /  TLX HBL\n6B915A' 1361162 '‘0682439'
#  'Customs RLS/ TLX HBL, pre-alert sent\nBC54C5' '0211525']
#
# Cleaning 'Inv status' column in sheet: OCT 2024
#
# Processing column: Inv status
# Available columns: ['CUSTOMER', 'CNTR#', 'SIZE', 'ETA PORT', 'ETA', 'SSL', 'Rail', 'APPT', 'TIME', 'TIME MISC', 'TRUCKER', 'TO', 'PU#', 'PU# MISC', 'LFD', 'OG', 'IG', 'NOTE', 'OP', 'Inv status', 'Dispatch', 'Sales Amount', 'Cost', 'CNTR AMOUNT', 'Profit', 'Profit Ratio', 'EIR', 'Co-loader']
#
# Extracted Inv Number:
# 0    154956
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# Name: Inv status, dtype: object
#
# Updated Inv status column:
# ['DONE' '']
#
# Generated Inv Number column:
# ['154956' '' '155092' '154958' '155067' '155283' '155193' '155370'
#  '155282' '155326' '155085' '155098' '155369' '155413' '155414' '154876'
#  '155434' '155435' '154877' '155463' '155678' '155190' '155746' '154945'
#  '155321' '155397' '156041' '156097' '155554']
#
# Cleaning Rail column in sheet: OCT 2024
#
# Processing column: Rail
#
# Updated Rail column:
# ['BNSF MEMPHIS' 'TACOMA, WA' 'UP-NS RAIL - AUSTELL (RAILRAMP)'
#  'LOS ANGELES, CA-WBCT-WEST BASIN CONTAINER TERMINAL' 'BNSF' 'BNSF LPC'
#  'UP' 'UP-MINNEAPOLIS' 'UP DENVER' 'GARDEN CITY TERMINAL' 'UP-EL PASO, TX'
#  'BNSF-FAIRBURN' 'BNSF-KANSAS' 'BNSF - KANSAS CITY LPKC'
#  'MIAMI PORT-POMTOC TERMINAL' 'NEW YORK-MAHER TERMINAL, BERTH 64'
#  'NS DETROIT, MI' 'X117 TERMINAL 18 CENTRAL' 'SEATTLE-T18, WA' 'CN HARVEY'
#  'NS CLEVELAND, OH' 'NS-AUSTELL'
#  'JACKSONVILLE-BLOUNT ISLAND MARINE TERMINAL' 'BNSF-CSX RAILROAD,COLUMBUS'
#  'ATLANTA-NS' 'UP GLOBAL 4' 'MAHER TERMINAL' 'BNSF-LPC' 'UNKNOWN']
#
# Processing sheet: NOV 2024
#
# Original CUSTOMER column:
# ['Super Linking' 'Loadstar-ship' 'APEX' 'Wing Ocean' 'WING SHIP 厦门翼舟'
#  'SUPER Linking' 'KUMI' '博信 ' 'Zhejiang Hangyu' 'META' 'WAYOTA' 'SA UNION'
#  'Rabbit Speed' 'FOREST' 'FOREST- NINGBO' 'ROHANA' 'LINK TRANS' 'Apex'
#  'FOREST- SHENZHEN' 'PG-NETWORK' 'Wayota' 'YIWU HANGJI' 'KRAKEN' 'Aspeed'
#  '创辰' 'PICO' 'Weitu' 'Ningbo Nanhua' 'Ningbo Jingda' 'PAQS' 'Link Trans'
#  'Titan']
#
# Cleaned CUSTOMER column after mapping:
# ['SUPER LINKING' 'LOADSTAR-SHIP' 'APEX' 'WING OCEAN' 'WING SHIP' 'KUMI'
#  '博信' 'ZHEJIANG HANGYU' 'META' 'WAYOTA' 'SA UNION' 'RABBIT SPEED' 'FOREST'
#  'FOREST-NINGBO' 'ROHANA' 'LINK TRANS' 'FOREST-SHENZHEN' 'PG-NETWORK'
#  'YIWU HANGJI' 'KRAKEN' 'ASPEED' '创辰' 'PICO' 'WEITU' 'NINGBO NANHUA'
#  'NINGBO JINGDA' 'PAQS' 'TITAN']
#
# Original CNTR# column:
# 0    TRLU8824328
# 1    NYKU4700927
# 2    OOLU8601345
# 3    SEKU5850192
# 4    FFAU1216234
# Name: CNTR#, dtype: object
#
# Cleaned CNTR# column:
# 0      TRLU8824328
# 1      NYKU4700927
# 2      OOLU8601345
# 3      SEKU5850192
# 4      FFAU1216234
#           ...
# 160    TCKU6643134
# 161    CSNU7114303
# 162    CXDU1597632
# 163    MATU2674390
# 164    MRSU3162969
# Name: CNTR#, Length: 165, dtype: object
#
# Original SIZE column:
# ['20GP' '40HQ' '40’HQ' '40 HQ' 45602 '40GP' '40HC' '45HC' 'JXLU7428460'
#  '20 GP']
#
# Cleaned SIZE column:
# ['20GP' '40HQ' '40’HQ' 'UNKNOWN' '40GP' '40HC' '45HC' 'JXLU7428460']
#
# Cleaning date column: ETA PORT
#
# Processing column: ETA PORT
# Original values:
# 0   2024-10-26
# 1   2024-10-30
# 2   2024-10-16
# 3   2024-10-13
# 4   2024-10-13
# Name: ETA PORT, dtype: datetime64[ns]
# Cleaned values:
# 0   2024-10-26
# 1   2024-10-30
# 2   2024-10-16
# 3   2024-10-13
# 4   2024-10-13
# Name: ETA PORT, dtype: datetime64[ns]
#
# Cleaning date column: ETA
#
# Processing column: ETA
# Original values:
# 0   2024-11-01
# 1   2024-10-30
# 2   2024-11-01
# 3   2024-11-01
# 4   2024-11-01
# Name: ETA, dtype: datetime64[ns]
# Cleaned values:
# 0   2024-11-01
# 1   2024-10-30
# 2   2024-11-01
# 3   2024-11-01
# 4   2024-11-01
# Name: ETA, dtype: datetime64[ns]
#
# Cleaning date column: APPT
#
# Processing column: APPT
# Original values:
# 0    2024-11-05 00:00:00
# 1    2024-11-07 00:00:00
# 2    2024-11-04 00:00:00
# 3    2024-11-08 00:00:00
# 4    2024-11-08 00:00:00
# Name: APPT, dtype: object
# Cleaned values:
# 0   2024-11-05
# 1   2024-11-07
# 2   2024-11-04
# 3   2024-11-08
# 4   2024-11-08
# Name: APPT, dtype: datetime64[ns]
#
# Cleaning date column: LFD
#
# Processing column: LFD
# Original values:
# 0   2024-11-06
# 1   2024-11-05
# 2   2024-11-03
# 3   2024-11-08
# 4   2024-11-11
# Name: LFD, dtype: datetime64[ns]
# Cleaned values:
# 0   2024-11-06
# 1   2024-11-05
# 2   2024-11-03
# 3   2024-11-08
# 4   2024-11-11
# Name: LFD, dtype: datetime64[ns]
#
# Cleaning date column: OG
#
# Processing column: OG
# Original values:
# 0   2024-11-04
# 1   2024-11-05
# 2   2024-11-03
# 3   2024-11-08
# 4   2024-11-08
# Name: OG, dtype: datetime64[ns]
# Cleaned values:
# 0   2024-11-04
# 1   2024-11-05
# 2   2024-11-03
# 3   2024-11-08
# 4   2024-11-08
# Name: OG, dtype: datetime64[ns]
#
# Cleaning date column: IG
#
# Processing column: IG
# Original values:
# 0   2024-11-05
# 1   2024-11-12
# 2   2024-11-05
# 3   2024-11-11
# 4   2024-11-11
# Name: IG, dtype: datetime64[ns]
# Cleaned values:
# 0   2024-11-05
# 1   2024-11-12
# 2   2024-11-05
# 3   2024-11-11
# 4   2024-11-11
# Name: IG, dtype: datetime64[ns]
#
# Cleaning SSL column in sheet: NOV 2024
#
# Original SSL column unique values:
# ['CMA' 'One' 'COSCO' 'Maersk' 'ONE' 'OOCL' 'CMA CGM' 'MSC' 'EMC' 'HAPAG'
#  'EVERGREEN' 'TS LINES' 'ZIM' 'WHL' 'SML' 'Evergreen' 'HMM' 'Hapag' 'YML'
#  'WAN HAI' 'Matson']
#
# Cleaned SSL column unique values:
# ['CMA' 'ONE' 'COSCO' 'MAERSK' 'OOCL' 'CMA CGM' 'MSC' 'EMC' 'HAPAG'
#  'EVERGREEN' 'TS LINES' 'ZIM' 'WHL' 'SML' 'HMM' 'YML' '' 'WAN HAI'
#  'MATSON']
#
# Cleaning TIME column in sheet: NOV 2024
#
# Processing column: TIME
#
# Valid TIME entries in TIME:
# [datetime.time(11, 0) datetime.time(8, 0) '' datetime.time(9, 30)
#  datetime.time(9, 0)]
#
# Invalid TIME entries moved to TIME MISC:
# [nan '10:00am' 'Drop' '12:30PM' '5:00PM' '9:00AM' '' '11:30AM' '929533066'
#  '8:30am/ 1:10pm' '10am' '2:30pm' ' ="81604026978"' 'Drop 12:30'
#  '客户自己约--提前2个工作日告知可预约交仓时间' '8am' '`' '11:00am' '?' 'FAT2-FH-342IY / 10 am']
#
# Cleaning PU# column in sheet: NOV 2024
#
# Processing column: PU#
#
# Valid PU# entries in PU#:
# ['' 'A55E1C' 'FF4EFC' 'A8CBB8' '9B976D' 'D63654' 'AE0657' '873E8E'
#  '7E1026' 'D191C7' '5CB281' 'E5A3B4' 'A9E29C' 'D1976D' '4FAC36' 'C0D262'
#  '0767FB' '9741A1' '93B9D3' '7EFDFF' '2F2E73' '7D94C1' 'CEF1D7']
#
# Invalid PU# entries moved to PU# MISC:
# [7097 '' nan 1571 4971 4892 4924 '73874A  ' 'AN sent' 1023 'PO# 62092'
#  'RCVD CI-PL, AN sent / \ncustoms released' 2726 'PO# 62198' 'PO# 33221'
#  'PO# 62290' 'PU# requested' 'PO# 62349' 'PO# 62350'
#  'received AN, PENDING CI-PL / TLX HBL / SWB' 'received CI-PL / TLX HBL '
#  'PO# 33222' 'PO# 0034157' 'PO# 62829' 1359924 1359907 2074155
#  'AN Sent, pending CI-PL, Pending TLX MBL & HBL' 2753514
#  'Pending TLX MBL & TLX HBL' 'TLX MBL,TLX HBL' 1079798 2753573 'na'
#  'PO# 34097' 62834 62831 62833 33684 33223 33683 'ISF on file'
#  'received CI-PL / ISF']
#
# Cleaning 'Inv status' column in sheet: NOV 2024
#
# Processing column: Inv status
# Available columns: ['CUSTOMER', 'CNTR#', 'SIZE', 'ETA PORT', 'ETA', 'SSL', 'Rail', 'APPT', 'TIME', 'TIME MISC', 'TRUCKER', 'TO', 'PU#', 'PU# MISC', 'LFD', 'OG', 'IG', 'NOTE', 'OP', 'Inv status', 'Dispatch', 'Sales Amount', 'Cost', 'CNTR AMOUNT', 'Profit', 'Profit Ratio', 'EIR', 'Co-loader']
#
# Extracted Inv Number:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: Inv status, dtype: object
#
# Updated Inv status column:
# ['' 'DONE']
#
# Generated Inv Number column:
# ['' '155739' '155744' '156092' '156088' '156091' '156093' '156094'
#  '155662' '155664' '155663' '156037' '156096' '155996' '155688' '155995']
#
# Cleaning Rail column in sheet: NOV 2024
#
# Processing column: Rail
#
# Updated Rail column:
# ['NS RAIL – CHARLOTTE' 'PORT LIBERTY BAYONNE' 'BNSF' 'NS--APPLIANCE PARK'
#  'NS -- APPLIANCE PARK' 'BNSF LOGISTICS PARK' 'UP-NS DETROIT'
#  'INDIANA RAIL ROAD COMPANY' 'UNKNOWN' 'BNSF CHICAGO'
#  'GARDEN CITY TERMINAL' 'NS-AUSTELL' 'TACOMA, WA'
#  'JACKSONVILLE CONTAINER TERMINAL' 'SEATTLE-SSA TERMINAL T5'
#  'NS-CLEVELAND' 'UP' 'LONG BEACH PORT' 'MOBILE, AL-APM TERMINALS MOBILE'
#  'LOS ANGELES, CA' 'BNSF LPC' 'TAMPA PORTS AMERICA'
#  'E425 APM TERMINALS, NEW YORK' 'CSX CLEVELAND' 'MAHER TERMINAL'
#  'LONG BEACH, CA' 'NS -- APPLIANCE PARK ？' 'NS APPLIANCE PARK' 'UP-G4'
#  'BNSF-LPC' 'SEAGIRT MARINE TERMINAL, BALTIMORE,MD' 'UPG4-CHICAGO'
#  'NORFOLK,VA(USORF)' 'CHARLOTTE - CSX RAILWAY'
#  'MIAMI-SOUTH FLORIDA CONTAINER TML' 'JOLIET' 'JACKSONVILLE' 'MOBILE, AL'
#  'CONLEY MARINE TERM' 'NS--ATLANTA' 'CHICAGO'
#  'LAX PORT-FENIX MARINE SERVICE' 'LAX PORT-WEST BASIN CONTAINER TER'
#  'SAVANNAH, GA' 'SAVANNAH' 'CN' 'BAYPORT CONTAINER TERMINAL'
#  'NS RAIL - COLUMBUS RICKENBACKER' 'SOUTH FLORIDA CONTAINER TERMINAL'
#  'CSX-ATLANTA,GA,FULTON' 'WBCT (WEST BASIN CONTAINER TERMINAL)'
#  'LONG BEACH (CA)']
#
# Cleaned data has been saved to cleaned_data_with_fixed_Rail.xlsx
